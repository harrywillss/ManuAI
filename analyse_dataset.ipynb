# %% [markdown]
# # Analyse NZ Bird Dataset
# This script analyses the 'recordings_data.csv' metadata file created when downloading the files.
#
# Bear in mind, this is analysing all of the

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = "logs/recordings_data.csv"
df = pd.read_csv(file_name)
df.head(15)
# Out:
#         id generic_name  scientific_name english_name        sex  \
# 0   668542        Ninox  novaeseelandiae     Morepork  uncertain
# 1   638197        Ninox  novaeseelandiae     Morepork  uncertain
# 2   602419        Ninox  novaeseelandiae     Morepork  uncertain
# 3   405536        Ninox  novaeseelandiae     Morepork        NaN
# 4   404843        Ninox  novaeseelandiae     Morepork       male
# 5   354393        Ninox  novaeseelandiae     Morepork        NaN
# 6   114338        Ninox  novaeseelandiae     Morepork        NaN
# 7    33770        Ninox  novaeseelandiae     Morepork        NaN
# 8   345370        Ninox  novaeseelandiae     Morepork        NaN
# 9   206471        Ninox  novaeseelandiae     Morepork        NaN
# 10  153818        Ninox  novaeseelandiae     Morepork        NaN
# 11  963598       Nestor     meridionalis         Kaka       male
# 12  963596       Nestor     meridionalis         Kaka       male
# 13  963595       Nestor     meridionalis         Kaka       male
# 14  959427       Nestor     meridionalis         Kaka       male
#
#                                   file_url  length  \
# 0   https://xeno-canto.org/668542/download      37
# 1   https://xeno-canto.org/638197/download      48
# 2   https://xeno-canto.org/602419/download      20
# 3   https://xeno-canto.org/405536/download      20
# 4   https://xeno-canto.org/404843/download      77
# 5   https://xeno-canto.org/354393/download      57
# 6   https://xeno-canto.org/114338/download      38
# 7    https://xeno-canto.org/33770/download      29
# 8   https://xeno-canto.org/345370/download      92
# 9   https://xeno-canto.org/206471/download      13
# 10  https://xeno-canto.org/153818/download      82
# 11  https://xeno-canto.org/963598/download      35
# 12  https://xeno-canto.org/963596/download      71
# 13  https://xeno-canto.org/963595/download      66
# 14  https://xeno-canto.org/959427/download      14
#
#                                          license  \
# 0   //creativecommons.org/licenses/by-nc-sa/4.0/
# 1   //creativecommons.org/licenses/by-nc-sa/4.0/
# 2         //creativecommons.org/licenses/by/4.0/
# 3   //creativecommons.org/licenses/by-nc-sa/4.0/
# 4   //creativecommons.org/licenses/by-nc-sa/4.0/
# 5   //creativecommons.org/licenses/by-nc-nd/4.0/
# 6   //creativecommons.org/licenses/by-nc-sa/3.0/
# 7   //creativecommons.org/licenses/by-nc-sa/3.0/
# 8   //creativecommons.org/licenses/by-nc-sa/4.0/
# 9   //creativecommons.org/licenses/by-nc-sa/4.0/
# 10  //creativecommons.org/licenses/by-nc-nd/3.0/
# 11  //creativecommons.org/licenses/by-nc-sa/4.0/
# 12  //creativecommons.org/licenses/by-nc-sa/4.0/
# 13  //creativecommons.org/licenses/by-nc-sa/4.0/
# 14  //creativecommons.org/licenses/by-nc-sa/4.0/
#
#                                              location bird_type  \
# 0      Whangārei_Heads,_Whangarei_District,_Northland      song
# 1               Te_Tii,_Far_North_District,_Northland      song
# 2                   Marlborough_District,_Marlborough      song
# 3             Charleston,_Buller_District,_West_Coast      song
# 4              Paringa,_Westland_District,_West_Coast      song
# 5                  Mount_Cargill,_Dunedin_City,_Otago      song
# 6   Bullock_Creek_Road,_Paparoa_National_Park,_Bul...      song
# 7                                     Pakihi,_Okarito      song
# 8              Barrytown,_Buller_District,_West_Coast      song
# 9   Bullock_Creek_Road,_Paparoa_National_Park,_Bul...      song
# 10  Fiordland_National_Park,_Southland_District,_S...      song
# 11  Mt_Bruce_National_Wildlife_Centre_(near__Mount...      song
# 12  Mt_Bruce_National_Wildlife_Centre_(near__Mount...      song
# 13  Mt_Bruce_National_Wildlife_Centre_(near__Mount...      song
# 14  Ngaherenga_DOC_campsite,_Pureora_Forest_Park,_...      song
#
#                                                  also    smp     seen  regnr  \
# 0                                                  []  48000       no    NaN
# 1                                                  []  48000  unknown    NaN
# 2                                                  []  44100       no    NaN
# 3                                                  []  48000       no    NaN
# 4                                                  []  48000       no    NaN
# 5                                                  []  48000       no    NaN
# 6                                                  []  44100      yes    NaN
# 7                                                  []  44100  unknown    NaN
# 8                                                  []  44100      yes    NaN
# 9                                                  []  48000       no    NaN
# 10                                                 []  48000      yes    NaN
# 11  ['Mohoua albicilla', 'Prosthemadera novaeseela...  44100      yes    NaN
# 12  ['Tadorna variegata', 'Mohoua albicilla', 'Pro...  44100      yes    NaN
# 13                               ['Mohoua albicilla']  44100      yes    NaN
# 14            ['Petroica longipes', 'Gerygone igata']  44100      yes    NaN
#
#                                       file      source
# 0   https://xeno-canto.org/668542/download  Xeno-Canto
# 1   https://xeno-canto.org/638197/download  Xeno-Canto
# 2   https://xeno-canto.org/602419/download  Xeno-Canto
# 3   https://xeno-canto.org/405536/download  Xeno-Canto
# 4   https://xeno-canto.org/404843/download  Xeno-Canto
# 5   https://xeno-canto.org/354393/download  Xeno-Canto
# 6   https://xeno-canto.org/114338/download  Xeno-Canto
# 7    https://xeno-canto.org/33770/download  Xeno-Canto
# 8   https://xeno-canto.org/345370/download  Xeno-Canto
# 9   https://xeno-canto.org/206471/download  Xeno-Canto
# 10  https://xeno-canto.org/153818/download  Xeno-Canto
# 11  https://xeno-canto.org/963598/download  Xeno-Canto
# 12  https://xeno-canto.org/963596/download  Xeno-Canto
# 13  https://xeno-canto.org/963595/download  Xeno-Canto
# 14  https://xeno-canto.org/959427/download  Xeno-Canto

# %%
generic_names = df['generic_name']
scientific_names = df['scientific_name']
english_names = df['english_name']
licenses = df['license']

# %%
# Show scientific Names with count above 20
scientific_name_counts = scientific_names.value_counts()
scientific_name_counts[scientific_name_counts > 20]
# Out:
# scientific_name
# novaeseelandiae    222
# melanura            78
# albicilla           44
# meridionalis        41
# macrocephala        39
# rufusater           33
# lateralis           30
# longipes            26
# Name: count, dtype: int64

# %%
# Show unique english names
unique_english_names = df['english_name'].unique()
unique_english_names
# Out:
# array(['Morepork', 'Kaka', 'Tui', 'Bellbird', 'Saddleback', 'Whitehead',
#        'Tomtit', 'Robin', 'Silvereye'], dtype=object)

# %%
# License count across dataset
license_counts = licenses.value_counts()
print(license_counts)
# Out:
# license
# //creativecommons.org/licenses/by-nc-sa/4.0/    478
# //creativecommons.org/licenses/by-nc-sa/3.0/     34
# //creativecommons.org/licenses/by-nc-nd/3.0/      7
# //creativecommons.org/licenses/by-nc-nd/2.5/      7
# //creativecommons.org/licenses/by-nc-nd/4.0/      5
# //creativecommons.org/licenses/by/4.0/            4
# //creativecommons.org/licenses/by-nc/4.0/         1
# Name: count, dtype: int64

# %%
sample_rates = df['smp'].value_counts()
print(sample_rates)
# Out:
# smp
# 44100    365
# 48000    169
# 22050      1
# 8000       1
# Name: count, dtype: int64

# %%
# Count number of .wav files within class subfolders (segments/{class}/), recursively
folder = "segments/"
# Get class names from subfolder names in segments/ (skip hidden/system folders)
if os.path.isdir(folder):
    classes = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name)) and not name.startswith('.') and not name.startswith('__')]
else:
    classes = []

class_segment_counts = {}
for class_name in classes:
    class_folder = os.path.join(folder, class_name)
    wav_count = 0
    for root, dirs, files in os.walk(class_folder):
        wav_count += sum(1 for f in files if f.endswith('.wav'))
    class_segment_counts[class_name] = wav_count

# Sort and print
overall = 0
for class_name, count in sorted(class_segment_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"Class: {class_name}, Segment Count: {count}")
    overall += count
print(f"Overall Segment Count: {overall}")
# Out:
# Class: morepork, Segment Count: 36671
# Class: tomtit, Segment Count: 36333
# Class: bellbird, Segment Count: 34097
# Class: silvereye, Segment Count: 28378
# Class: tui, Segment Count: 20156
# Class: greywarbler, Segment Count: 16889
# Class: kiwi, Segment Count: 7752
# Class: robin, Segment Count: 5668
# Class: kea, Segment Count: 2877
# Class: whitehead, Segment Count: 1926
# Class: kokako, Segment Count: 1168
# Class: fantail, Segment Count: 1158
# Class: kaka, Segment Count: 1149
# Class: parakeet, Segment Count: 1099
# Class: pukeko, Segment Count: 1080
# Class: saddleback, Segment Count: 944
# Class: stitchbird, Segment Count: 570
# Class: yellowhead, Segment Count: 567
# Class: kingfisher, Segment Count: 235
# Class: kereru, Segment Count: 201
# Overall Segment Count: 198918

# %%
# Average segment count
average_segment_count = sum(class_segment_counts.values()) / len(class_segment_counts) if class_segment_counts else 0
print(f"Average Segment Count: {average_segment_count}")
# Out:
# Average Segment Count: 9945.9

# %%
# Count amount of files in downloads/
folder = 'downloads/'
num_files = len([f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))])
print(f"Number of files in '{folder}': {num_files}")
# Out:
# Number of files in 'downloads/': 195597
