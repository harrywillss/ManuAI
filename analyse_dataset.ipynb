# %% [markdown]
# # Analyse NZ Bird Dataset
# This script analyses the 'recordings_data.csv' metadata file created when downloading the files.
#
# Bear in mind, this is analysing all of the

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = "logs/recordings_data.csv"
df = pd.read_csv(file_name)
df.head(15)
# Out:
#         id generic_name scientific_name                english_name  \
# 0   955810      Apteryx        mantelli                  Brown Kiwi
# 1   638200      Apteryx        mantelli                  Brown Kiwi
# 2   152944      Apteryx          owenii         Little Spotted Kiwi
# 3    33754      Apteryx          owenii         Little Spotted Kiwi
# 4   952952      Apteryx          owenii         Little Spotted Kiwi
# 5    88143      Apteryx          owenii         Little Spotted Kiwi
# 6   152953       Cygnus         atratus                  Black Swan
# 7   959021      Tadorna       variegata           Paradise Shelduck
# 8   959019      Tadorna       variegata           Paradise Shelduck
# 9   960622      Tadorna       variegata           Paradise Shelduck
# 10  466576   Callipepla     californica            California Quail
# 11  153008   Callipepla     californica            California Quail
# 12  467378   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
# 13  467376   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
# 14  207340   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
#
#              sex                                file_url  length
# 0           male  https://xeno-canto.org/955810/download      50
# 1            NaN  https://xeno-canto.org/638200/download      22
# 2           male  https://xeno-canto.org/152944/download      25
# 3            NaN   https://xeno-canto.org/33754/download      26
# 4           male  https://xeno-canto.org/952952/download      23
# 5            NaN   https://xeno-canto.org/88143/download      51
# 6            NaN  https://xeno-canto.org/152953/download      41
# 7   female, male  https://xeno-canto.org/959021/download      17
# 8   female, male  https://xeno-canto.org/959019/download      80
# 9      uncertain  https://xeno-canto.org/960622/download      27
# 10           NaN  https://xeno-canto.org/466576/download      53
# 11           NaN  https://xeno-canto.org/153008/download      45
# 12  female, male  https://xeno-canto.org/467378/download      33
# 13          male  https://xeno-canto.org/467376/download      28
# 14           NaN  https://xeno-canto.org/207340/download      33

# %%
generic_names = df['generic_name']
scientific_names = df['scientific_name']
english_names = df['english_name']

# %%
# Show scientific Names with count above 20
scientific_name_counts = scientific_names.value_counts()
scientific_name_counts[scientific_name_counts > 20]
# Out:
# scientific_name
# novaeseelandiae    244
# melanura            77
# albicilla           44
# fuliginosa          43
# australis           42
# meridionalis        41
# macrocephala        39
# igata               37
# mystery             35
# chloris             33
# rufusater           33
# novaezelandiae      33
# lateralis           30
# merula              30
# punctatus           29
# dimidiata           28
# longipes            26
# coelebs             25
# philomelos          23
# variegata           21
# cincta              21
# Name: count, dtype: int64

# %%
# Show unique english names
unique_english_names = df['english_name'].unique()
unique_english_names
# Out:
# array(['Brown Kiwi', 'Little Spotted Kiwi', 'Black Swan',
#        'Paradise Shelduck', 'California Quail',
#        'Pacific Long-tailed Cuckoo', 'Shining Bronze Cuckoo',
#        'Spotted Dove', 'Lilac-crowned Fruit Dove',
#        'Pacific Imperial Pigeon', 'Pigeon', 'Chatham Pigeon', 'Weka',
#        'Australasian Swamphen', 'Takahe', "Baillon's Crake",
#        'Variable Oystercatcher', 'Chatham Oystercatcher', 'Wrybill',
#        'Plover', 'Chatham Snipe', 'White-tailed Tropicbird',
#        'Little Penguin', 'Yellow-eyed Penguin',
#        'White-faced Storm Petrel', "Buller's Albatross", 'Cape Petrel',
#        'Broad-billed Prion', 'Fairy Prion', 'Fulmar Prion',
#        'Magenta Petrel', 'Herald Petrel', 'Chatham Petrel', 'Grey Petrel',
#        'Westland Petrel', 'Sooty Shearwater', 'Flesh-footed Shearwater',
#        'Fluttering Shearwater', 'South Georgia Diving Petrel',
#        'Common Diving Petrel', 'Swamp Harrier', 'Morepork',
#        'Sacred Kingfisher', 'Kaka', 'Yellow-crowned Parakeet',
#        'Red-crowned Parakeet', 'Rifleman', 'Tui', 'Bellbird',
#        'Grey Gerygone', 'Chatham Gerygone', 'Kokako', 'Saddleback',
#        'Stitchbird', 'Australian Magpie', 'Yellowhead', 'Whitehead',
#        'Pipipi', 'Fantail', 'Rarotonga Monarch', 'Tomtit', 'Robin',
#        'Black Robin', 'Eurasian Skylark', 'Cook Reed Warbler', 'Fernbird',
#        'Silvereye', 'Common Myna', 'Common Starling', 'Song Thrush',
#        'Common Blackbird', 'House Sparrow', 'Dunnock', 'Pipit',
#        'Common Chaffinch', 'European Greenfinch', 'Lesser Redpoll',
#        'European Goldfinch', 'Yellowhammer', 'Soundscape',
#        'Identity unknown', 'Okarito Kiwi', 'Australasian Shoveler',
#        'Pacific Black Duck', 'Mallard', 'Grey Teal', 'Brown Teal',
#        'Campbell Teal', 'Scaup', 'Common Pheasant', 'Eurasian Coot',
#        'Spotless Crake', 'Oystercatcher', 'Pied Stilt', 'Black Stilt',
#        'Masked Lapwing', 'Double-banded Plover', 'Shore Dotterel',
#        'Bar-tailed Godwit', 'Silver Gull', 'Black-billed Gull',
#        'Kelp Gull', 'Caspian Tern', 'White-fronted Tern',
#        'Antarctic Tern', 'Black-fronted Tern', 'Red-tailed Tropicbird',
#        'Snares Penguin', 'Erect-crested Penguin', 'Wandering Albatross',
#        'Antipodean Albatross', 'Southern Royal Albatross',
#        'Northern Royal Albatross', 'Shy Albatross', 'Chatham Albatross',
#        "Salvin's Albatross", "Leach's Storm Petrel",
#        'Northern Giant Petrel', 'Grey-faced Petrel',
#        'Soft-plumaged Petrel', 'Black-winged Petrel', 'Black Petrel',
#        "Hutton's Shearwater", 'Little Shearwater', 'Australasian Gannet',
#        'Pitt Shag', 'Spotted Shag', 'King Shag', 'Chatham Shag',
#        'White-faced Heron', 'Chattering Kingfisher', 'Falcon', 'Kea',
#        'Eastern Rosella', 'Chatham Parakeet', "Malherbe's Parakeet",
#        "Kuhl's Lorikeet", 'Blue Lorikeet', 'Rockwren', 'Welcome Swallow',
#        'Rarotonga Starling', 'Common Redpoll', 'Kakapo'], dtype=object)
