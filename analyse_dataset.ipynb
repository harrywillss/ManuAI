# %% [markdown]
# # Analyse NZ Bird Dataset
# This script analyses the 'recordings_data.csv' metadata file created when downloading the files.
#
# Bear in mind, this is analysing all of the

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = "logs/recordings_data.csv"
df = pd.read_csv(file_name)
df.head(15)
# Out:
#         id generic_name scientific_name                english_name  \
# 0   955810      Apteryx        mantelli                  Brown Kiwi
# 1   638200      Apteryx        mantelli                  Brown Kiwi
# 2   152944      Apteryx          owenii         Little Spotted Kiwi
# 3    33754      Apteryx          owenii         Little Spotted Kiwi
# 4   952952      Apteryx          owenii         Little Spotted Kiwi
# 5    88143      Apteryx          owenii         Little Spotted Kiwi
# 6   152953       Cygnus         atratus                  Black Swan
# 7   959021      Tadorna       variegata           Paradise Shelduck
# 8   959019      Tadorna       variegata           Paradise Shelduck
# 9   960622      Tadorna       variegata           Paradise Shelduck
# 10  466576   Callipepla     californica            California Quail
# 11  153008   Callipepla     californica            California Quail
# 12  467378   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
# 13  467376   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
# 14  207340   Urodynamis       taitensis  Pacific Long-tailed Cuckoo
#
#              sex                                file_url  length  \
# 0           male  https://xeno-canto.org/955810/download      50
# 1            NaN  https://xeno-canto.org/638200/download      22
# 2           male  https://xeno-canto.org/152944/download      25
# 3            NaN   https://xeno-canto.org/33754/download      26
# 4           male  https://xeno-canto.org/952952/download      23
# 5            NaN   https://xeno-canto.org/88143/download      51
# 6            NaN  https://xeno-canto.org/152953/download      41
# 7   female, male  https://xeno-canto.org/959021/download      17
# 8   female, male  https://xeno-canto.org/959019/download      80
# 9      uncertain  https://xeno-canto.org/960622/download      27
# 10           NaN  https://xeno-canto.org/466576/download      53
# 11           NaN  https://xeno-canto.org/153008/download      45
# 12  female, male  https://xeno-canto.org/467378/download      33
# 13          male  https://xeno-canto.org/467376/download      28
# 14           NaN  https://xeno-canto.org/207340/download      33
#
#                                          license  \
# 0   //creativecommons.org/licenses/by-nc-sa/4.0/
# 1   //creativecommons.org/licenses/by-nc-sa/4.0/
# 2   //creativecommons.org/licenses/by-nc-nd/3.0/
# 3   //creativecommons.org/licenses/by-nc-sa/3.0/
# 4   //creativecommons.org/licenses/by-nc-sa/4.0/
# 5   //creativecommons.org/licenses/by-nc-nd/2.5/
# 6   //creativecommons.org/licenses/by-nc-nd/3.0/
# 7   //creativecommons.org/licenses/by-nc-sa/4.0/
# 8   //creativecommons.org/licenses/by-nc-sa/4.0/
# 9   //creativecommons.org/licenses/by-nc-sa/4.0/
# 10  //creativecommons.org/licenses/by-nc-sa/4.0/
# 11  //creativecommons.org/licenses/by-nc-nd/3.0/
# 12  //creativecommons.org/licenses/by-nc-sa/4.0/
# 13  //creativecommons.org/licenses/by-nc-sa/4.0/
# 14  //creativecommons.org/licenses/by-nc-sa/4.0/
#
#                                              location  \
# 0   Tawharanui_Regional_Park_(near__Tāwharanui_Pen...
# 1               Te_Tii,_Far_North_District,_Northland
# 2                            Tiritiri_Matangi_Island_
# 3                            Tiritiri_Matangi_Island_
# 4                              Whangaparāoa,_Auckland
# 5                                       Kapiti_Island
# 6           Waimangu,_Rotorua_District,_Bay_Of_Plenty
# 7                             Tiritiri_Matangi_Island
# 8                             Tiritiri_Matangi_Island
# 9   Tangiwai,_Ruapehu_District_Council,_Manawatū-W...
# 10                     Taupo,_Taupo_District,_Waikato
# 11        Christchurch,_Christchurch_City,_Canterbury
# 12                      Westland_District,_West_Coast
# 13                      Westland_District,_West_Coast
# 14  Gunn_Lake_Nature_Trail,_Fiordland_National_Par...
#
#                                             bird_type  \
# 0   song,_I__dont_know_what_the_other_sound_is,_Ki...
# 1                                                song
# 2                                                song
# 3                                                song
# 4                                                song
# 5                                          duet,_song
# 6                                                song
# 7                       call,_song,_Flying_away_calls
# 8                       call,_song,_Flying_away_calls
# 9                                          call,_song
# 10                                               song
# 11                                               song
# 12                                         call,_song
# 13                                               song
# 14                                               song
#
#                                                  also    smp     seen regnr  \
# 0                                                  []  44100       no   NaN
# 1                                                  []  48000       no   NaN
# 2                                                  []  48000      yes   NaN
# 3                                                  []  44100  unknown   NaN
# 4                                                  []  44100       no   NaN
# 5                                                  []  44100  unknown   NaN
# 6                                                  []  48000      yes   NaN
# 7      ['Philesturnus rufusater', 'Mohoua albicilla']  44100       no   NaN
# 8      ['Philesturnus rufusater', 'Mohoua albicilla']  44100       no   NaN
# 9                                  ['Gerygone igata']  44100      yes   NaN
# 10  ['Fringilla coelebs', 'Turdus merula', 'Rhipid...  48000      yes   NaN
# 11                                                 []  48000      yes   NaN
# 12             ['Fringilla coelebs', 'Turdus merula']  44100      yes   NaN
# 13                                                 []  44100       no   NaN
# 14  ['Fringilla coelebs', 'Turdus philomelos', 'Zo...  44100      yes   NaN
#
#                                       file
# 0   https://xeno-canto.org/955810/download
# 1   https://xeno-canto.org/638200/download
# 2   https://xeno-canto.org/152944/download
# 3    https://xeno-canto.org/33754/download
# 4   https://xeno-canto.org/952952/download
# 5    https://xeno-canto.org/88143/download
# 6   https://xeno-canto.org/152953/download
# 7   https://xeno-canto.org/959021/download
# 8   https://xeno-canto.org/959019/download
# 9   https://xeno-canto.org/960622/download
# 10  https://xeno-canto.org/466576/download
# 11  https://xeno-canto.org/153008/download
# 12  https://xeno-canto.org/467378/download
# 13  https://xeno-canto.org/467376/download
# 14  https://xeno-canto.org/207340/download

# %%
generic_names = df['generic_name']
scientific_names = df['scientific_name']
english_names = df['english_name']
licenses = df['license']

# %%
# Show scientific Names with count above 20
scientific_name_counts = scientific_names.value_counts()
scientific_name_counts[scientific_name_counts > 20]
# Out:
# scientific_name
# novaeseelandiae    254
# melanura            78
# albicilla           44
# fuliginosa          43
# australis           42
# meridionalis        41
# macrocephala        39
# igata               37
# mystery             35
# chloris             33
# rufusater           33
# novaezelandiae      33
# lateralis           30
# merula              30
# punctatus           29
# dimidiata           28
# longipes            26
# coelebs             25
# philomelos          23
# variegata           21
# cincta              21
# Name: count, dtype: int64

# %%
# Show unique english names
unique_english_names = df['english_name'].unique()
unique_english_names
# Out:
# array(['Brown Kiwi', 'Little Spotted Kiwi', 'Black Swan',
#        'Paradise Shelduck', 'California Quail',
#        'Pacific Long-tailed Cuckoo', 'Shining Bronze Cuckoo',
#        'Spotted Dove', 'Lilac-crowned Fruit Dove',
#        'Pacific Imperial Pigeon', 'Pigeon', 'Chatham Pigeon', 'Weka',
#        'Australasian Swamphen', 'Takahe', "Baillon's Crake",
#        'Variable Oystercatcher', 'Chatham Oystercatcher', 'Wrybill',
#        'Plover', 'Chatham Snipe', 'White-tailed Tropicbird',
#        'Little Penguin', 'Yellow-eyed Penguin',
#        'White-faced Storm Petrel', "Buller's Albatross", 'Cape Petrel',
#        'Broad-billed Prion', 'Fairy Prion', 'Fulmar Prion',
#        'Magenta Petrel', 'Herald Petrel', 'Chatham Petrel', 'Grey Petrel',
#        'Westland Petrel', 'Sooty Shearwater', 'Flesh-footed Shearwater',
#        'Fluttering Shearwater', 'South Georgia Diving Petrel',
#        'Common Diving Petrel', 'Swamp Harrier', 'Morepork',
#        'Sacred Kingfisher', 'Kaka', 'Yellow-crowned Parakeet',
#        'Red-crowned Parakeet', 'Rifleman', 'Tui', 'Bellbird',
#        'Grey Gerygone', 'Chatham Gerygone', 'Kokako', 'Saddleback',
#        'Stitchbird', 'Australian Magpie', 'Yellowhead', 'Whitehead',
#        'Pipipi', 'Fantail', 'Rarotonga Monarch', 'Tomtit', 'Robin',
#        'Black Robin', 'Eurasian Skylark', 'Cook Reed Warbler', 'Fernbird',
#        'Silvereye', 'Common Myna', 'Common Starling', 'Song Thrush',
#        'Common Blackbird', 'House Sparrow', 'Dunnock', 'Pipit',
#        'Common Chaffinch', 'European Greenfinch', 'Lesser Redpoll',
#        'European Goldfinch', 'Yellowhammer', 'Soundscape',
#        'Identity unknown', 'Okarito Kiwi', 'Australasian Shoveler',
#        'Pacific Black Duck', 'Mallard', 'Grey Teal', 'Brown Teal',
#        'Campbell Teal', 'Scaup', 'Common Pheasant', 'Eurasian Coot',
#        'Spotless Crake', 'Oystercatcher', 'Pied Stilt', 'Black Stilt',
#        'Masked Lapwing', 'Double-banded Plover', 'Shore Dotterel',
#        'Bar-tailed Godwit', 'Silver Gull', 'Black-billed Gull',
#        'Kelp Gull', 'Caspian Tern', 'White-fronted Tern',
#        'Antarctic Tern', 'Black-fronted Tern', 'Red-tailed Tropicbird',
#        'Snares Penguin', 'Erect-crested Penguin', 'Wandering Albatross',
#        'Antipodean Albatross', 'Southern Royal Albatross',
#        'Northern Royal Albatross', 'Shy Albatross', 'Chatham Albatross',
#        "Salvin's Albatross", "Leach's Storm Petrel",
#        'Northern Giant Petrel', 'Grey-faced Petrel',
#        'Soft-plumaged Petrel', 'Black-winged Petrel', 'Black Petrel',
#        "Hutton's Shearwater", 'Little Shearwater', 'Australasian Gannet',
#        'Pitt Shag', 'Spotted Shag', 'King Shag', 'Chatham Shag',
#        'White-faced Heron', 'Chattering Kingfisher', 'Falcon', 'Kea',
#        'Eastern Rosella', 'Chatham Parakeet', "Malherbe's Parakeet",
#        "Kuhl's Lorikeet", 'Blue Lorikeet', 'Rockwren', 'Welcome Swallow',
#        'Rarotonga Starling', 'Common Redpoll', 'Kakapo'], dtype=object)

# %%
# License count across dataset
license_counts = licenses.value_counts()
print(license_counts)
# Out:
# license
# //creativecommons.org/licenses/by-nc-sa/4.0/    1321
# //creativecommons.org/licenses/by-nc-sa/3.0/     175
# //creativecommons.org/licenses/by-nc-nd/3.0/      49
# //creativecommons.org/licenses/by-nc-nd/4.0/      34
# //creativecommons.org/licenses/by-nc-nd/2.5/      19
# //creativecommons.org/licenses/by/4.0/            12
# //creativecommons.org/licenses/by-nc/4.0/          1
# Name: count, dtype: int64

# %%
sample_rates = df['smp'].value_counts()
print(sample_rates)
# Out:
# smp
# 44100    1088
# 48000     483
# 32000      17
# 8000       14
# 22050       6
# 96000       2
# 16000       1
# Name: count, dtype: int64

# %%
# Count number of .wav files within class subfolders (segments/{class}/), recursively
import os

folder = "segments/"
# Get class names from subfolder names in segments/ (skip hidden/system folders)
if os.path.isdir(folder):
    classes = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name)) and not name.startswith('.') and not name.startswith('__')]
else:
    classes = []

class_segment_counts = {}
for class_name in classes:
    class_folder = os.path.join(folder, class_name)
    wav_count = 0
    for root, dirs, files in os.walk(class_folder):
        wav_count += sum(1 for f in files if f.endswith('.wav'))
    class_segment_counts[class_name] = wav_count

# Sort and print
for class_name, count in sorted(class_segment_counts.items(), key=lambda x: x[1], reverse=True):
    print(f"Class: {class_name}, Segment Count: {count}")
# Out:
# Class: tui, Segment Count: 8532
# Class: bellbird, Segment Count: 3352
# Class: robin, Segment Count: 1675
# Class: silvereye, Segment Count: 1449
# Class: whitehead, Segment Count: 1304
# Class: fantail, Segment Count: 1220
# Class: kaka, Segment Count: 1164
# Class: saddleback, Segment Count: 962
# Class: tomtit, Segment Count: 851
# Class: morepork, Segment Count: 719

# %%
# Average segment count
average_segment_count = sum(class_segment_counts.values()) / len(class_segment_counts) if class_segment_counts else 0
print(f"Average Segment Count: {average_segment_count}")
# Out:
# Average Segment Count: 2122.8
